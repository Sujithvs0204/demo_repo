# %%
print("hello world")
# Out:
# hello world

# %%
# !git config --global user.email "vssujith2000@gmail.com"
# !git config --global user.name "Sujithvs0204"

# %%
# 2. Clone the repo
# Replace 'YOUR_TOKEN' with your GitHub Personal Access Token
# !git clone https://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@github.com/Sujithvs0204/demo_repo.git
# Out:
# Cloning into 'demo_repo'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 18 (delta 2), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), done.
# Resolving deltas: 100% (2/2), done.

# %%
# Move the file into the repo folder
# !cp "/content/delete.ipynb" "/content/demo_repo/"

# Verify it's in there
# !ls /content/demo_repo/
# Out:
# cp: cannot stat '/content/delete.ipynb': No such file or directory
# agri_risk  climate_risk.py  README.md

# %%
# !ls /content/demo_repo/
# Out:
# agri_risk  climate_risk.py  README.md

# %%
# Install nbconvert if it's not already installed
# !pip install nbconvert

# %%
# Save the current notebook as 'delete.ipynb' in the /content/ directory
# '__file__' typically refers to the current script, but in an IPython/Jupyter environment,
# it's usually handled by calling the nbconvert command directly on the notebook itself.
# Colab notebooks often have an internal name like 'Untitled.ipynb' or similar before being saved/opened.
# Assuming the user wants to name it 'delete.ipynb' as per previous context.

# Note: To make this robust, it's better to get the current notebook's path directly.
# However, a simpler way to 'save' the current state as a file is often to download and re-upload,
# or to use a magic command if available to access the current notebook's content.
# For programmatic saving as a file, `nbconvert` needs the input notebook path.
# The current working directory in Colab is /content/, so we can assume the notebook is effectively 'here'.

# A common workaround to get the current notebook's path in Colab:
import os

# This method assumes the notebook's actual name in the Colab backend is 'Untitled.ipynb'
# or similar before being explicitly saved or if accessed via a specific path.
# A more direct approach to export the *currently running* notebook:
# !jupyter nbconvert --to notebook --output "/content/delete.ipynb" "$(jupyter --paths | grep data/share/jupyter/nbconvert/templates | head -n 1)/notebook.ipynb"
# Out:
# [NbConvertApp] WARNING | pattern '/notebook.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# ...

# %%
# Verify the file exists in /content/
# !ls /content/delete.ipynb
# Out:
# ls: cannot access '/content/delete.ipynb': No such file or directory
