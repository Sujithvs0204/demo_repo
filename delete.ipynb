# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujithvs0204/demo_repo/blob/main/delete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
# !git config --global user.email "vssujith2000@gmail.com"
# !git config --global user.name "Sujithvs0204"

# %%
# 2. Clone the repo
# Replace 'YOUR_TOKEN' with your GitHub Personal Access Token
# !git clone https://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@github.com/Sujithvs0204/demo_repo.git
# Out:
# Cloning into 'demo_repo'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 18 (delta 2), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls /content/
# Out:
# delete.ipynb  demo_repo  sample_data

# %%
# Move the file into the repo folder
# !cp "/content/delete.ipynb" "/content/demo_repo/"

# Verify it's in there
# !ls /content/demo_repo/
# Out:
# agri_risk  climate_risk.py  delete.ipynb  README.md

# %%
# !ls /content/demo_repo/
# Out:
# agri_risk  climate_risk.py  delete.ipynb  README.md

# %%
# Verify the file exists in /content/
# !ls /content/delete.ipynb
# Out:
# /content/delete.ipynb

# %%
# Change directory to the cloned repository
# %cd /content/demo_repo/
# Out:
# /content/demo_repo

# %%
# Add the new file to the staging area
# !git add delete.ipynb

# %%
# Commit the changes
# !git commit -m "Add delete.ipynb from Colab"
# Out:
# [main 509f182] Add delete.ipynb from Colab
#  1 file changed, 448 insertions(+)
#  create mode 100644 delete.ipynb

# %%
# Push the changes to GitHub
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 5.59 KiB | 5.59 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Sujithvs0204/demo_repo.git
#    bb188f1..509f182  main -> main

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3616f9f7-d0ac-452c-814d-bc0104d7368d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3616f9f7-d0ac-452c-814d-bc0104d7368d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Verify the file exists in /content/
# !ls /content/delete.ipynb
# Out:
# /content/delete.ipynb
